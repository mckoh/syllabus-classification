# %% [markdown]
# # Automatic Syllabus Classification

# %%
from os import listdir
from os.path import join
from datetime import datetime as dt

from syllabus_classificaiton.functions import load_curriculum
from syllabus_classificaiton.functions import transform_curriculum
from syllabus_classificaiton.functions import classify_curriculum
from syllabus_classificaiton.functions import save_classification

# %%
start_time = dt.now()

for file in listdir("input"):
    if file.endswith(".json"):
        src_file = file
        dst_file = file.split(".")[0]+".md"

        in_path = join("input", src_file)
        out_path = join("output", dst_file)

        x = load_curriculum(file_path=in_path)
        x = transform_curriculum(json_curriculum=x)
        c = classify_curriculum(txt_curriculum=x)
        s = save_classification(output_path=out_path, txt_classification=c)

        print("Operation successful?", s)
        print("##########################\n")

print("TOTAL TIME:", dt.now()-start_time)
# Out:
# Loading curriculum data from input/machine_learning_deep_learning_e.json.
# --> Time needed for this step: 0:00:00.000487
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000012
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:22.010743
#
# Saving classification to output/machine_learning_deep_learning_e.md.
# --> Time needed for this step: 0:00:00.001015
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/study_trip_e.json.
# --> Time needed for this step: 0:00:00.000454
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000024
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:21.787846
#
# Saving classification to output/study_trip_e.md.
# --> Time needed for this step: 0:00:00.000566
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/systemische_innovation.json.
# --> Time needed for this step: 0:00:00.000342
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000032
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:23.666622
#
# Saving classification to output/systemische_innovation.md.
# --> Time needed for this step: 0:00:00.000598
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/big_data_processing_e.json.
# --> Time needed for this step: 0:00:00.000279
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000036
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:22.562103
#
# Saving classification to output/big_data_processing_e.md.
# --> Time needed for this step: 0:00:00.000840
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/softwareentwicklung_1.json.
# --> Time needed for this step: 0:00:00.000395
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000033
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:25.472927
#
# Saving classification to output/softwareentwicklung_1.md.
# --> Time needed for this step: 0:00:00.000963
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/statistisches_lernen_2_lab.json.
# --> Time needed for this step: 0:00:00.000795
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000026
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:19.910302
#
# Saving classification to output/statistisches_lernen_2_lab.md.
# --> Time needed for this step: 0:00:00.000806
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/businessethik_compliance_recht.json.
# --> Time needed for this step: 0:00:00.000492
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000053
#
# Classifying curriculum data.
# --> Time needed for this step: 0:21:47.814935
#
# Saving classification to output/businessethik_compliance_recht.md.
# --> Time needed for this step: 0:00:00.001769
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/datenvisualisierung_visual_analytics_wp.json.
# --> Time needed for this step: 0:00:00.000291
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000043
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:26.344291
#
# Saving classification to output/datenvisualisierung_visual_analytics_wp.md.
# --> Time needed for this step: 0:00:00.000529
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/kolloquium_zur_masterarbeit.json.
# --> Time needed for this step: 0:00:00.000865
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000043
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:27.177520
#
# Saving classification to output/kolloquium_zur_masterarbeit.md.
# --> Time needed for this step: 0:00:00.001121
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/statistisches_lernen_2.json.
# --> Time needed for this step: 0:00:00.000524
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000046
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:22.178816
#
# Saving classification to output/statistisches_lernen_2.md.
# --> Time needed for this step: 0:00:00.001004
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/softwareentwicklung_2_lab.json.
# --> Time needed for this step: 0:00:00.000736
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000026
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:21.209486
#
# Saving classification to output/softwareentwicklung_2_lab.md.
# --> Time needed for this step: 0:00:00.000964
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/data_science_for_engineering_natural_sciences_e.json.
# --> Time needed for this step: 0:00:00.000757
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000046
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:26.151071
#
# Saving classification to output/data_science_for_engineering_natural_sciences_e.md.
# --> Time needed for this step: 0:00:00.001079
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/artificial_intelligence_e.json.
# --> Time needed for this step: 0:00:00.000742
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000043
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:27.097897
#
# Saving classification to output/artificial_intelligence_e.md.
# --> Time needed for this step: 0:00:00.001035
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/praxisprojekt.json.
# --> Time needed for this step: 0:00:00.000866
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000029
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:21.842308
#
# Saving classification to output/praxisprojekt.md.
# --> Time needed for this step: 0:00:00.001130
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/statistisches_lernen_1_lab.json.
# --> Time needed for this step: 0:00:00.000875
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000022
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:18.528044
#
# Saving classification to output/statistisches_lernen_1_lab.md.
# --> Time needed for this step: 0:00:00.001033
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/trends_in_data_science_wp.json.
# --> Time needed for this step: 0:00:00.000383
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000027
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:31.985822
#
# Saving classification to output/trends_in_data_science_wp.md.
# --> Time needed for this step: 0:00:00.000907
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/data_science_for_business_commerce_e.json.
# --> Time needed for this step: 0:00:00.000296
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000023
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:34.287973
#
# Saving classification to output/data_science_for_business_commerce_e.md.
# --> Time needed for this step: 0:00:00.001132
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/statistisches_lernen_1.json.
# --> Time needed for this step: 0:00:00.000714
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000027
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:25.466339
#
# Saving classification to output/statistisches_lernen_1.md.
# --> Time needed for this step: 0:00:00.001048
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/leadership_im_team_projektmanagement.json.
# --> Time needed for this step: 0:00:00.000739
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000024
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:18.828120
#
# Saving classification to output/leadership_im_team_projektmanagement.md.
# --> Time needed for this step: 0:00:00.000940
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/softwareentwicklung_2.json.
# --> Time needed for this step: 0:00:00.000536
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000041
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:26.063255
#
# Saving classification to output/softwareentwicklung_2.md.
# --> Time needed for this step: 0:00:00.001035
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/wissenschaftliches_arbeiten.json.
# --> Time needed for this step: 0:00:00.000733
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000023
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:19.810973
#
# Saving classification to output/wissenschaftliches_arbeiten.md.
# --> Time needed for this step: 0:00:00.001116
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/data_engineering_lab.json.
# --> Time needed for this step: 0:00:00.000689
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000025
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:22.105272
#
# Saving classification to output/data_engineering_lab.md.
# --> Time needed for this step: 0:00:00.001015
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/masterarbeit.json.
# --> Time needed for this step: 0:00:00.000697
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000021
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:22.749983
#
# Saving classification to output/masterarbeit.md.
# --> Time needed for this step: 0:00:00.001019
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/softwareentwicklung_1_lab.json.
# --> Time needed for this step: 0:00:00.000732
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000046
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:20.176417
#
# Saving classification to output/softwareentwicklung_1_lab.md.
# --> Time needed for this step: 0:00:00.001137
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/anwendungsorientierte_analyseplattformen_wp.json.
# --> Time needed for this step: 0:00:00.000731
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000024
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:33.541009
#
# Saving classification to output/anwendungsorientierte_analyseplattformen_wp.md.
# --> Time needed for this step: 0:00:00.001135
#
# Operation successful? True
# ##########################
#
# Loading curriculum data from input/data_engineering.json.
# --> Time needed for this step: 0:00:00.000737
#
# Transforming curriculum data to String format.
# --> Time needed for this step: 0:00:00.000025
#
# Classifying curriculum data.
# --> Time needed for this step: 0:00:28.280090
#
# Saving classification to output/data_engineering.md.
# --> Time needed for this step: 0:00:00.001073
#
# Operation successful? True
# ##########################
#
# TOTAL TIME: 0:31:57.103946
