# %% [markdown]
# # Tiroler Bildungskatalog
#
# [Tiroler Bildungskatalog online](https://tiroler-bildungskatalog.at/)

# %%
from pandas import read_excel

# %% [markdown]
# ## Load and understand data

# %%
data = read_excel("input/TuWas/TUWAS-38_20251107.xlsx")
data["length"] = data["kursbeschreibung"].map(lambda x: len(x))
data["length"].describe()
# Out:
# count    149287.000000
# mean        652.498208
# std         835.430923
# min           1.000000
# 25%         186.000000
# 50%         387.000000
# 75%         792.000000
# max        6000.000000
# Name: length, dtype: float64
